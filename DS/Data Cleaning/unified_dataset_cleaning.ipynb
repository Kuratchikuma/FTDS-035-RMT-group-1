# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Loading

# %%
df_bandung = pd.read_csv (r'C:\Users\Alew\OneDrive - upi.edu\Hacktiv8\phase2\FTDS-035-RMT-group-1\raw_files\Bandung_raw.csv')
df_jakarta = pd.read_csv (r'C:\Users\Alew\OneDrive - upi.edu\Hacktiv8\phase2\FTDS-035-RMT-group-1\raw_files\Jakarta_raw.csv')
df_surabaya = pd.read_csv (r'C:\Users\Alew\OneDrive - upi.edu\Hacktiv8\phase2\FTDS-035-RMT-group-1\raw_files\surabaya_raw.csv')

# %% [markdown]
# ## Combining dataset

# %% [markdown]
# ### Define kolom baru dari masing masing kota

# %%
# Menambahkan kolom 'kota' ke masing-masing DataFrame
df_jakarta['kota'] = 'Jakarta'
df_bandung['kota'] = 'Bandung'
df_surabaya['kota'] = 'Surabaya'

# %% [markdown]
# ### Conbine semua dataset

# %%
# Menggabungkan DataFrame jika diperlukan
df_combined = pd.concat([df_jakarta, df_bandung, df_surabaya], ignore_index=True)

# %% [markdown]
# ### Atur penempatan kolom 'kota' di sebelah 'title'

# %%
# Mengatur ulang kolom untuk menempatkan 'kota' di sebelah kanan 'title'
if 'title' in df_combined.columns and 'kota' in df_combined.columns:
    # Ambil semua kolom kecuali 'kota' dan 'title'
    columns = [col for col in df_combined.columns if col not in ['title', 'kota']]
    
    # Buat urutan kolom baru
    new_order = ['title'] + ['kota'] + columns
    
    # Susun ulang DataFrame
    df_combined = df_combined[new_order]
else:
    print("Kolom 'title' atau 'kota' tidak ditemukan dalam DataFrame.")

# %% [markdown]
# ## Save dataframe yang telah di combine

# %%
df_combined.to_csv('tempat_ngopi_combined.csv', index=False)

# %% [markdown]
# ## Baca dataset yang telah di combine

# %%
df = pd.read_csv('tempat_ngopi_combined.csv')
df
# Out:
#                           title      kota  rate   cuisine       location  \
# 0                  Kohicha Cafe   Jakarta  4.36  ['Kafe']  Kelapa Gading
# 1     Hang Tuah Kopi & Toastery   Jakarta  4.53  ['Kafe']     Pecenongan
# 2                Toko Kopi Tuku   Jakarta  4.00  ['Kafe']      Fatmawati
# 3            Kopi Susu Bu Lurah   Jakarta  3.93  ['Kafe']      Setiabudi
# 4             Kopi Selamat Pagi   Jakarta  4.34  ['Kafe']  Kelapa Gading
# ...                         ...       ...   ...       ...            ...
# 4495                    Kitcoff  Surabaya  0.00  ['Kafe']         Ngagel
# 4496                      Avere  Surabaya  0.00  ['Kafe']         Ngagel
# 4497                Kangen Ortu  Surabaya  0.00  ['Kafe']       Sukolilo
# 4498                     L'Fash  Surabaya  0.00  ['Kafe']       Sukolilo
# 4499         Cerita Kita Eatery  Surabaya  0.00  ['Kafe']       Wonocolo
#
#                                   address  \
# 0     Ruko Gading Kirana, Blok A6A No. 21
# 1                                     NaN
# 2                                     NaN
# 3                              Warung MJS
# 4                                     NaN
# ...                                   ...
# 4495                                  NaN
# 4496                                  NaN
# 4497                                  NaN
# 4498                                  NaN
# 4499                                  NaN
#
#                                                  street  price_from  \
# 0     Jl. Boulevard Artha Gading, Kelapa Gading, Jak...  Rp. 50.000
# 1      Jl. Pecenongan No. 37, Pecenongan, Jakarta Pusat  Rp. 50.000
# 2     Jl. Cipete Raya No. 7 (Sebelah Alfamart), Fatm...       Rp. 0
# 3     Jl. Setiabudi Tengah No. 11, Setiabudi, Jakart...       Rp. 0
# 4     Jl. Summagung III No. 17, Kelapa Gading, Jakar...  Rp. 50.000
# ...                                                 ...         ...
# 4495          Jl. Ngagel Madya No. 85, Ngagel, Surabaya       Rp. 0
# 4496     Jl. Ngagel Jaya Barat No. 52, Ngagel, Surabaya       Rp. 0
# 4497        Jl. Raya Manyar No. 67B, Sukolilo, Surabaya       Rp. 0
# 4498  Jl. Manyar Kartika Barat No. 7, Sukolilo, Sura...       Rp. 0
# 4499  Jl. Siwalankerto Timur No. 185, Wonocolo, Sura...       Rp. 0
#
#        price_till                                                url  ...  \
# 0     Rp. 100.000  https://pergikuliner.com/restaurants/jakarta/k...  ...
# 1     Rp. 100.000  https://pergikuliner.com/restaurants/jakarta/h...  ...
# 2      Rp. 50.000  https://pergikuliner.com/restaurants/jakarta/t...  ...
# 3      Rp. 50.000  https://pergikuliner.com/restaurants/jakarta/k...  ...
# 4     Rp. 100.000  https://pergikuliner.com/restaurants/jakarta/k...  ...
# ...           ...                                                ...  ...
# 4495   Rp. 50.000  https://pergikuliner.com/restaurants/surabaya/...  ...
# 4496   Rp. 50.000  https://pergikuliner.com/restaurants/surabaya/...  ...
# 4497   Rp. 50.000  https://pergikuliner.com/restaurants/surabaya/...  ...
# 4498   Rp. 50.000  https://pergikuliner.com/restaurants/surabaya/...  ...
# 4499   Rp. 50.000  https://pergikuliner.com/restaurants/surabaya/...  ...
#
#       wifi_available smoking_area_available  outdoor_seat_available  \
# 0               True                   True                    True
# 1               True                   True                    True
# 2               True                   True                    True
# 3               True                   True                    True
# 4               True                   True                    True
# ...              ...                    ...                     ...
# 4495            True                   True                    True
# 4496            True                   True                    True
# 4497            True                   True                   False
# 4498            True                   True                    True
# 4499            True                   True                   False
#
#       full_time_available  vip_room_available  reservation_available  \
# 0                   False               False                   True
# 1                   False               False                   True
# 2                   False               False                  False
# 3                   False                True                   True
# 4                   False               False                   True
# ...                   ...                 ...                    ...
# 4495                False               False                   True
# 4496                False               False                   True
# 4497                False               False                  False
# 4498                False                True                   True
# 4499                False                True                   True
#
#       parking_area_available  \
# 0                       True
# 1                       True
# 2                      False
# 3                       True
# 4                       True
# ...                      ...
# 4495                    True
# 4496                    True
# 4497                    True
# 4498                    True
# 4499                    True
#
#                                               review_11  \
# 0     Food is excellent, absolutely delicious. The p...
# 1     Buka dari pagi, komplir menu sarapan sampe mak...
# 2     Toko tuku pertama kali di cipete ini, ternyata...
# 3     *Review untuk pesan antar (via gojek) atau tak...
# 4     I need my morning coffee. Cuzz ke Kopi Selamat...
# ...                                                 ...
# 4495                                               None
# 4496                                               None
# 4497                                               None
# 4498                                               None
# 4499                                               None
#
#                                               review_12  \
# 0     Makanan disini semua enak. Makanan & minumanny...
# 1     [Breakast Nikmat khas Singapore di Pecenongan ...
# 2     Rasanya beda sama yang biasa saya minum, tapi ...
# 3     Sabtu sore maen kesini khusus buat nyoba es ko...
# 4     Tempatnya enak, cukup nyantai, pet-friendly, a...
# ...                                                 ...
# 4495                                               None
# 4496                                               None
# 4497                                               None
# 4498                                               None
# 4499                                               None
#
#                                               review_13
# 0     Cafe vibes Jepang di Kelapa Gading. Aku surah ...
# 1     kwetiaw seafoodrasanya gurih, smokey flavor. i...
# 2     Akhirnyaa cobain yang slushy juga, dan ini bar...
# 3     Es kopi susu bu lurah salah satu yang gue suka...
# 4     Baru pertama kali coba ke kopi selamat pagi, t...
# ...                                                 ...
# 4495                                               None
# 4496                                               None
# 4497                                               None
# 4498                                               None
# 4499                                               None
#
# [4500 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4500 entries, 0 to 4499
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   title                   4500 non-null   object
#  1   kota                    4500 non-null   object
#  2   rate                    4500 non-null   float64
#  3   cuisine                 4469 non-null   object
#  4   location                4500 non-null   object
#  5   address                 1815 non-null   object
#  6   street                  4500 non-null   object
#  7   price_from              4500 non-null   object
#  8   price_till              4483 non-null   object
#  9   url                     4500 non-null   object
#  10  description             0 non-null      float64
#  11  opening_hours           4418 non-null   object
#  12  wifi_available          4500 non-null   bool
#  13  smoking_area_available  4500 non-null   bool
#  14  outdoor_seat_available  4500 non-null   bool
#  15  full_time_available     4500 non-null   bool
#  16  vip_room_available      4500 non-null   bool
#  17  reservation_available   4500 non-null   bool
#  18  parking_area_available  4500 non-null   bool
#  19  review_11               4500 non-null   object
#  20  review_12               4500 non-null   object
#  21  review_13               4500 non-null   object
# dtypes: bool(7), float64(2), object(13)
# memory usage: 558.2+ KB

# %% [markdown]
# ## Mencari missing value

# %%
df.isnull().sum()
# Out:
# title                        0
# kota                         0
# rate                         0
# cuisine                     31
# location                     0
# address                   2685
# street                       0
# price_from                   0
# price_till                  17
# url                          0
# description               4500
# opening_hours               82
# wifi_available               0
# smoking_area_available       0
# outdoor_seat_available       0
# full_time_available          0
# vip_room_available           0
# reservation_available        0
# parking_area_available       0
# review_11                    0
# review_12                    0
# review_13                    0
# dtype: int64

# %% [markdown]
# ## Mencari data duplikat

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Combine kolom 'location', 'address' dan 'street' menjadi satu kolom 'full_adress'

# %%
# Membuat kolom 'full_address'
df['full_address'] = df[['location', 'address', 'street']].apply(lambda x: ', '.join(x.dropna()), axis=1)

# %% [markdown]
# ## Susun agar kolom 'full_adress' ada di sebelah kanan dari kolom 'kota'

# %%
# Susun ulang kolom untuk menempatkan 'full_address' di sebelah kanan 'kota'
if 'kota' in df.columns and 'full_address' in df.columns:
    # Ambil semua kolom dan buat list baru untuk urutan yang diinginkan
    new_order = []
    
    # Menambahkan kolom sebelum 'kota' dan 'full_address' di urutan yang diinginkan
    for col in df.columns:
        if col == 'kota':
            new_order.append(col)  # Tambahkan 'kota'
            new_order.append('full_address')  # Tambahkan 'full_address' setelahnya
        elif col != 'full_address':  # Hindari menambahkan 'full_address' lagi
            new_order.append(col)

    # Susun ulang DataFrame berdasarkan urutan kolom yang baru
    df = df[new_order]
else:
    print("Kolom 'kota' atau 'full_address' tidak ditemukan dalam DataFrame.")

# Menampilkan DataFrame hasil
print(df)
# Out:
#                           title      kota  \
# 0                  Kohicha Cafe   Jakarta
# 1     Hang Tuah Kopi & Toastery   Jakarta
# 2                Toko Kopi Tuku   Jakarta
# 3            Kopi Susu Bu Lurah   Jakarta
# 4             Kopi Selamat Pagi   Jakarta
# ...                         ...       ...
# 4495                    Kitcoff  Surabaya
# 4496                      Avere  Surabaya
# 4497                Kangen Ortu  Surabaya
# 4498                     L'Fash  Surabaya
# 4499         Cerita Kita Eatery  Surabaya
#
#                                            full_address  rate   cuisine  \
# 0     Kelapa Gading, Ruko Gading Kirana, Blok A6A No...  4.36  ['Kafe']
# 1     Pecenongan, Jl. Pecenongan No. 37, Pecenongan,...  4.53  ['Kafe']
# 2     Fatmawati, Jl. Cipete Raya No. 7 (Sebelah Alfa...  4.00  ['Kafe']
# 3     Setiabudi, Warung MJS, Jl. Setiabudi Tengah No...  3.93  ['Kafe']
# 4     Kelapa Gading, Jl. Summagung III No. 17, Kelap...  4.34  ['Kafe']
# ...                                                 ...   ...       ...
# 4495  Ngagel, Jl. Ngagel Madya No. 85, Ngagel, Surabaya  0.00  ['Kafe']
# 4496  Ngagel, Jl. Ngagel Jaya Barat No. 52, Ngagel, ...  0.00  ['Kafe']
# 4497  Sukolilo, Jl. Raya Manyar No. 67B, Sukolilo, S...  0.00  ['Kafe']
# 4498  Sukolilo, Jl. Manyar Kartika Barat No. 7, Suko...  0.00  ['Kafe']
# 4499  Wonocolo, Jl. Siwalankerto Timur No. 185, Wono...  0.00  ['Kafe']
#
#            location                              address  \
# 0     Kelapa Gading  Ruko Gading Kirana, Blok A6A No. 21
# 1        Pecenongan                                  NaN
# 2         Fatmawati                                  NaN
# 3         Setiabudi                           Warung MJS
# 4     Kelapa Gading                                  NaN
# ...             ...                                  ...
# 4495         Ngagel                                  NaN
# 4496         Ngagel                                  NaN
# 4497       Sukolilo                                  NaN
# 4498       Sukolilo                                  NaN
# 4499       Wonocolo                                  NaN
#
#                                                  street  price_from  \
# 0     Jl. Boulevard Artha Gading, Kelapa Gading, Jak...  Rp. 50.000
# 1      Jl. Pecenongan No. 37, Pecenongan, Jakarta Pusat  Rp. 50.000
# 2     Jl. Cipete Raya No. 7 (Sebelah Alfamart), Fatm...       Rp. 0
# 3     Jl. Setiabudi Tengah No. 11, Setiabudi, Jakart...       Rp. 0
# 4     Jl. Summagung III No. 17, Kelapa Gading, Jakar...  Rp. 50.000
# ...                                                 ...         ...
# 4495          Jl. Ngagel Madya No. 85, Ngagel, Surabaya       Rp. 0
# 4496     Jl. Ngagel Jaya Barat No. 52, Ngagel, Surabaya       Rp. 0
# 4497        Jl. Raya Manyar No. 67B, Sukolilo, Surabaya       Rp. 0
# 4498  Jl. Manyar Kartika Barat No. 7, Sukolilo, Sura...       Rp. 0
# 4499  Jl. Siwalankerto Timur No. 185, Wonocolo, Sura...       Rp. 0
#
#        price_till  ... wifi_available  smoking_area_available  \
# 0     Rp. 100.000  ...           True                    True
# 1     Rp. 100.000  ...           True                    True
# 2      Rp. 50.000  ...           True                    True
# 3      Rp. 50.000  ...           True                    True
# 4     Rp. 100.000  ...           True                    True
# ...           ...  ...            ...                     ...
# 4495   Rp. 50.000  ...           True                    True
# 4496   Rp. 50.000  ...           True                    True
# 4497   Rp. 50.000  ...           True                    True
# 4498   Rp. 50.000  ...           True                    True
# 4499   Rp. 50.000  ...           True                    True
#
#      outdoor_seat_available  full_time_available  vip_room_available  \
# 0                      True                False               False
# 1                      True                False               False
# 2                      True                False               False
# 3                      True                False                True
# 4                      True                False               False
# ...                     ...                  ...                 ...
# 4495                   True                False               False
# 4496                   True                False               False
# 4497                  False                False               False
# 4498                   True                False                True
# 4499                  False                False                True
#
#       reservation_available  parking_area_available  \
# 0                      True                    True
# 1                      True                    True
# 2                     False                   False
# 3                      True                    True
# 4                      True                    True
# ...                     ...                     ...
# 4495                   True                    True
# 4496                   True                    True
# 4497                  False                    True
# 4498                   True                    True
# 4499                   True                    True
#
#                                               review_11  \
# 0     Food is excellent, absolutely delicious. The p...
# 1     Buka dari pagi, komplir menu sarapan sampe mak...
# 2     Toko tuku pertama kali di cipete ini, ternyata...
# 3     *Review untuk pesan antar (via gojek) atau tak...
# 4     I need my morning coffee. Cuzz ke Kopi Selamat...
# ...                                                 ...
# 4495                                               None
# 4496                                               None
# 4497                                               None
# 4498                                               None
# 4499                                               None
#
#                                               review_12  \
# 0     Makanan disini semua enak. Makanan & minumanny...
# 1     [Breakast Nikmat khas Singapore di Pecenongan ...
# 2     Rasanya beda sama yang biasa saya minum, tapi ...
# 3     Sabtu sore maen kesini khusus buat nyoba es ko...
# 4     Tempatnya enak, cukup nyantai, pet-friendly, a...
# ...                                                 ...
# 4495                                               None
# 4496                                               None
# 4497                                               None
# 4498                                               None
# 4499                                               None
#
#                                               review_13
# 0     Cafe vibes Jepang di Kelapa Gading. Aku surah ...
# 1     kwetiaw seafoodrasanya gurih, smokey flavor. i...
# 2     Akhirnyaa cobain yang slushy juga, dan ini bar...
# 3     Es kopi susu bu lurah salah satu yang gue suka...
# 4     Baru pertama kali coba ke kopi selamat pagi, t...
# ...                                                 ...
# 4495                                               None
# 4496                                               None
# 4497                                               None
# 4498                                               None
# 4499                                               None
#
# [4500 rows x 23 columns]

# %% [markdown]
# ## drop kolom 'location', 'address', 'street'

# %%
# Hapus kolom 'location' dan 'address'
df = df.drop(columns=['location', 'address', 'street'])

# %% [markdown]
# ## Cleaning kolom 'cuisine'

# %%
df['cuisine'].unique
# Out:
# <bound method Series.unique of 0       ['Kafe']
# 1       ['Kafe']
# 2       ['Kafe']
# 3       ['Kafe']
# 4       ['Kafe']
#           ...
# 4495    ['Kafe']
# 4496    ['Kafe']
# 4497    ['Kafe']
# 4498    ['Kafe']
# 4499    ['Kafe']
# Name: cuisine, Length: 4500, dtype: object>

# %%
df['cuisine'] = df['cuisine'].str.replace(r"[\[\]']", '', regex=True)

# %% [markdown]
# ## Drop kolomn 'description' karena tidak ada data apapun di dalamnya

# %%
df = df.drop(columns=['description'])

# %% [markdown]
# ## Mengganti string 'None' menjadi 'Tidak ada review'

# %%
# Ganti None dan np.nan dengan 'Tidak ada review'
df[['review_11', 'review_12', 'review_13']] = df[['review_11', 'review_12', 'review_13']].apply(lambda col: col.replace({'None': 'Tidak ada review', np.nan: 'Tidak ada review'}))

# %% [markdown]
# ## Menghapus 'Rp.' dan '.' pada kolom 'price_from'

# %%
df['price_from'] = df['price_from'].str.replace('Rp. ', '', regex=False).str.replace('.', '').astype(float)
df['price_till'] = df['price_till'].str.replace('Rp. ', '', regex=False).str.replace('.', '').astype(float)
# Out:
# C:\Users\Alew\AppData\Local\Temp\ipykernel_3744\3514946874.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['price_from'] = df['price_from'].str.replace('Rp. ', '', regex=False).str.replace('.', '').astype(float)
# C:\Users\Alew\AppData\Local\Temp\ipykernel_3744\3514946874.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['price_till'] = df['price_till'].str.replace('Rp. ', '', regex=False).str.replace('.', '').astype(float)

# %% [markdown]
# ## Mengisi NaN menjadi X2 dari kolom price from

# %%
df['price_till'] = df['price_till'].fillna(df['price_from'] * 2)

# %% [markdown]
# ## Mengisi missing value pada kolom 'opening_hours' menjadi 'Tidak ada data'

# %%
# Mengisi missing value pada kolom 'opening_hours' dengan "tidak ada data"
df['opening_hours'] = df['opening_hours'].fillna('tidak ada data')

# %%
df.isnull().sum()
# Out:
# title                      0
# kota                       0
# full_address               0
# rate                       0
# cuisine                   31
# price_from                 0
# price_till                 0
# url                        0
# opening_hours              0
# wifi_available             0
# smoking_area_available     0
# outdoor_seat_available     0
# full_time_available        0
# vip_room_available         0
# reservation_available      0
# parking_area_available     0
# review_11                  0
# review_12                  0
# review_13                  0
# dtype: int64

# %%
# Menampilkan baris-baris yang memiliki missing value di kolom 'cuisine', termasuk kolom lainnya
missing_cuisine_data = df[df['cuisine'].isnull()]

# Menampilkan hasil
print(missing_cuisine_data)
# Out:
#                                               title      kota  \
# 341                             XXI Cafe - Puri XXI   Jakarta
# 996                                  Common Grounds   Jakarta
# 1802                                   Warkopinlah!   Bandung
# 1816                                     Kopi Moyan   Bandung
# 2139                                       XXI Cafe   Bandung
# 2153                                    Sabana Kopi   Bandung
# 2188                         Kopi Saring Sinar Pagi   Bandung
# 2224                                  d'Kopi Memori   Bandung
# 2437                                       Circle K   Bandung
# 3002  Cafe Bromo - Sheraton Surabaya Hotel & Towers  Surabaya
# 3092                                    Kultur Haus  Surabaya
# 3390                                    Kopi Perang  Surabaya
# 3466                        Lazizaa Chicken & Pizza  Surabaya
# 3651                                     Pot N Brew  Surabaya
# 3716                                Kedai Cafetaria  Surabaya
# 3741                                      Coma Cafe  Surabaya
# 3794                 Mini Cafe Galaxy Fried Chicken  Surabaya
# 3799                                     Kopikirlah  Surabaya
# 3857                                  Kopi Mama Ury  Surabaya
# 3878                Garden Cafe - Ciputra World XXI  Surabaya
# 3879                    XXI Cafe - Pakuwon Mall XXI  Surabaya
# 3880                    XXI Cafe - Fairway Nine XXI  Surabaya
# 3918                              Cafe Serbu Bosque  Surabaya
# 4043                                         S-Cone  Surabaya
# 4047                               Kedai Teko Merah  Surabaya
# 4052                            Coffee Break Eleven  Surabaya
# 4062                                    Kofie Paste  Surabaya
# 4073                             Lampu Merah Coffee  Surabaya
# 4098                                      Casa Loma  Surabaya
# 4281                                           Moji  Surabaya
# 4340                            JDR Coffee & Eatery  Surabaya
#
#                                            full_address  rate cuisine  \
# 341   ['Puri'], Puri Indah Mall, Lantai 2, Cinema XX...  4.04     NaN
# 996   ['Kelapa Gading'], Mall of Indonesia, Lantai G...  3.96     NaN
# 1802  ['Antapani'], Jl. Terusan Jakarta No. 78A, Ant...  5.00     NaN
# 1816        ['Riau'], Jl. Anggrek No. 30, Riau, Bandung  3.62     NaN
# 2139  ['Cihampelas'], Cihampelas Walk, Lantai Lower ...  4.00     NaN
# 2153  ['Sunda'], Jl. Baranang Siang No. 7, Sunda, Ba...  4.00     NaN
# 2188         ['Riau'], Jl. Lombok No. 30, Riau, Bandung  3.40     NaN
# 2224  ['Dago Bawah'], Salon Memori, Jl. Dago No. 185...  3.80     NaN
# 2437  ['Buah Batu'], Jl. Solontongan No. 8, Buah Bat...  4.20     NaN
# 3002  ['Tegalsari'], Sheraton Surabaya Hotel & Tower...  4.85     NaN
# 3092  ['Mulyorejo'], One East, Jl. Kertajaya Indah N...  4.08     NaN
# 3390  ['Sambikerep'], Fresh Market Citraland, Jl. Ta...  3.20     NaN
# 3466  ['Gayungan'], Jl. Ketintang No. 192, Gayungan,...  4.60     NaN
# 3651  ['Sambikerep'], Days Surabaya, Jl. Taman Gapur...  3.00     NaN
# 3716  ['Semolowaru'], Ruko Citypride, Blok A No. 1, ...  0.00     NaN
# 3741  ['Wiyung'], Perumahan Gunung Sari Indah, Blok ...  0.00     NaN
# 3794  ['Ngagel'], Jl. Ngagel Rejo No. 33, Ngagel, Su...  0.00     NaN
# 3799  ['Gubeng'], Jl. Dharmawangsa No. 101, Gubeng, ...  0.00     NaN
# 3857  ['Sukolilo'], Jl. Manyar Indah II No. 1, Sukol...  0.00     NaN
# 3878  ['Dukuh Pakis'], Ciputra World, Lantai 4, Cine...  0.00     NaN
# 3879  ['Wiyung'], Pakuwon Mall, Lantai 2M, Cinema XX...  0.00     NaN
# 3880  ['Dukuh Pakis'], Fairway Nine Mall, Lantai 4, ...  0.00     NaN
# 3918  ['Wonokromo'], Royal Plaza, Lantai 3, Jl. Jend...  0.00     NaN
# 4043  ['Mulyorejo'], Jl. Dr. Ir. H. Soekarno No. 34,...  0.00     NaN
# 4047  ['Ngagel'], Jl. Ngagel Jaya Barat No. 50, Ngag...  0.00     NaN
# 4052  ['Rungkut'], Jl. Medokan Asri Barat Blok M12 N...  0.00     NaN
# 4062  ['Gubeng'], Badokan Surabaya, Lantai 2, Jl. Gu...  0.00     NaN
# 4073  ['Ngagel'], Jl. Ngagel Dadi V No. 54, Ngagel, ...  0.00     NaN
# 4098  ['Wonocolo'], Jl. Margorejo Indah No. 84, Wono...  0.00     NaN
# 4281  ['Wonokromo'], Royal Plaza, Lantai Ground, Jl....  0.00     NaN
# 4340  ['Wonokromo'], Royal Plaza, Lantai 3, Studio F...  0.00     NaN
#
#       price_from  price_till  \
# 341      50000.0    100000.0
# 996      50000.0    100000.0
# 1802         0.0     50000.0
# 1816         0.0     50000.0
# 2139     50000.0    100000.0
# 2153         0.0     50000.0
# 2188         0.0     50000.0
# 2224         0.0     50000.0
# 2437         0.0     50000.0
# 3002    100000.0    200000.0
# 3092     50000.0    100000.0
# 3390         0.0     50000.0
# 3466         0.0     50000.0
# 3651         0.0     50000.0
# 3716         0.0     50000.0
# 3741         0.0     50000.0
# 3794         0.0     50000.0
# 3799         0.0     50000.0
# 3857         0.0     50000.0
# 3878     50000.0    100000.0
# 3879     50000.0    100000.0
# 3880     50000.0    100000.0
# 3918         0.0     50000.0
# 4043         0.0     50000.0
# 4047         0.0     50000.0
# 4052         0.0     50000.0
# 4062         0.0     50000.0
# 4073         0.0     50000.0
# 4098         0.0     50000.0
# 4281         0.0     50000.0
# 4340         0.0     50000.0
#
#                                                     url  \
# 341   https://pergikuliner.com/restaurants/jakarta/x...
# 996   https://pergikuliner.com/restaurants/jakarta/c...
# 1802  https://pergikuliner.com/restaurants/bandung/w...
# 1816  https://pergikuliner.com/restaurants/bandung/k...
# 2139  https://pergikuliner.com/restaurants/bandung/x...
# 2153  https://pergikuliner.com/restaurants/bandung/s...
# 2188  https://pergikuliner.com/restaurants/bandung/k...
# 2224  https://pergikuliner.com/restaurants/bandung/d...
# 2437  https://pergikuliner.com/restaurants/bandung/c...
# 3002  https://pergikuliner.com/restaurants/surabaya/...
# 3092  https://pergikuliner.com/restaurants/surabaya/...
# 3390  https://pergikuliner.com/restaurants/surabaya/...
# 3466  https://pergikuliner.com/restaurants/surabaya/...
# 3651  https://pergikuliner.com/restaurants/surabaya/...
# 3716  https://pergikuliner.com/restaurants/surabaya/...
# 3741  https://pergikuliner.com/restaurants/surabaya/...
# 3794  https://pergikuliner.com/restaurants/surabaya/...
# 3799  https://pergikuliner.com/restaurants/surabaya/...
# 3857  https://pergikuliner.com/restaurants/surabaya/...
# 3878  https://pergikuliner.com/restaurants/surabaya/...
# 3879  https://pergikuliner.com/restaurants/surabaya/...
# 3880  https://pergikuliner.com/restaurants/surabaya/...
# 3918  https://pergikuliner.com/restaurants/surabaya/...
# 4043  https://pergikuliner.com/restaurants/surabaya/...
# 4047  https://pergikuliner.com/restaurants/surabaya/...
# 4052  https://pergikuliner.com/restaurants/surabaya/...
# 4062  https://pergikuliner.com/restaurants/surabaya/...
# 4073  https://pergikuliner.com/restaurants/surabaya/...
# 4098  https://pergikuliner.com/restaurants/surabaya/...
# 4281  https://pergikuliner.com/restaurants/surabaya/...
# 4340  https://pergikuliner.com/restaurants/surabaya/...
#
#                                           opening_hours  wifi_available  \
# 341                      Senin - Minggu (11:00 - 21:00)           False
# 996                      Senin - Minggu (10:00 - 22:00)           False
# 1802                     Senin - Minggu (11:00 - 23:00)           False
# 1816       Selasa - Minggu (07:00 - 14:00), Senin Tutup           False
# 2139                     Senin - Minggu (10:00 - 22:00)           False
# 2153                                     tidak ada data           False
# 2188                     Senin - Minggu (06:30 - 11:30)           False
# 2224  Senin - Sabtu (07:30 - 21:00), Minggu (07:45 -...            True
# 2437                                     tidak ada data           False
# 3002                     Senin - Minggu (06:00 - 22:00)            True
# 3092  Senin - Jumat (09:00 - 24:00), Sabtu - Minggu ...            True
# 3390                     Senin - Minggu (07:00 - 15:00)           False
# 3466                     Senin - Minggu (07:00 - 22:00)            True
# 3651                     Senin - Minggu (08:00 - 20:00)           False
# 3716                     Senin - Minggu (10:00 - 02:00)            True
# 3741  Senin - Jumat (14:00 - 22:00), Sabtu (14:00 - ...            True
# 3794                     Senin - Minggu (11:00 - 23:00)           False
# 3799                     Senin - Minggu (10:00 - 23:00)            True
# 3857                     Senin - Minggu (10:00 - 22:00)           False
# 3878                                     tidak ada data           False
# 3879                                     tidak ada data           False
# 3880                                     tidak ada data           False
# 3918                     Senin - Minggu (10:00 - 22:00)           False
# 4043        Senin - Sabtu (08:00 - 17:00), Minggu Tutup           False
# 4047  Senin - Kamis (11:00 - 23:00), Jumat (13:00 - ...           False
# 4052                     Senin - Minggu (08:00 - 02:00)            True
# 4062                     Senin - Minggu (07:00 - 24:00)            True
# 4073                     Senin - Minggu (11:00 - 23:00)            True
# 4098                     Senin - Minggu (08:00 - 22:00)            True
# 4281                     Senin - Minggu (10:00 - 21:30)           False
# 4340                     Senin - Minggu (10:00 - 21:30)           False
#
#       smoking_area_available  outdoor_seat_available  full_time_available  \
# 341                    False                   False                False
# 996                    False                   False                False
# 1802                   False                   False                False
# 1816                   False                   False                False
# 2139                   False                   False                False
# 2153                   False                   False                False
# 2188                   False                   False                False
# 2224                    True                    True                False
# 2437                   False                   False                False
# 3002                   False                   False                False
# 3092                    True                    True                False
# 3390                   False                   False                False
# 3466                    True                   False                False
# 3651                    True                    True                False
# 3716                    True                   False                False
# 3741                    True                    True                False
# 3794                    True                   False                False
# 3799                    True                   False                False
# 3857                    True                   False                False
# 3878                   False                   False                False
# 3879                   False                   False                False
# 3880                   False                   False                False
# 3918                   False                   False                False
# 4043                    True                   False                False
# 4047                    True                    True                False
# 4052                    True                   False                False
# 4062                    True                   False                False
# 4073                    True                   False                False
# 4098                    True                    True                False
# 4281                   False                   False                False
# 4340                   False                   False                False
#
#       vip_room_available  reservation_available  parking_area_available  \
# 341                False                  False                    True
# 996                False                  False                    True
# 1802               False                  False                   False
# 1816               False                  False                   False
# 2139               False                  False                    True
# 2153               False                  False                   False
# 2188               False                  False                   False
# 2224               False                   True                    True
# 2437               False                  False                    True
# 3002                True                   True                    True
# 3092               False                   True                    True
# 3390               False                  False                   False
# 3466               False                  False                    True
# 3651               False                   True                    True
# 3716               False                   True                    True
# 3741               False                   True                    True
# 3794               False                   True                    True
# 3799               False                   True                    True
# 3857               False                  False                   False
# 3878               False                  False                    True
# 3879               False                  False                    True
# 3880               False                  False                    True
# 3918               False                  False                    True
# 4043               False                  False                    True
# 4047               False                  False                    True
# 4052               False                   True                    True
# 4062               False                  False                    True
# 4073               False                  False                    True
# 4098               False                  False                    True
# 4281               False                  False                    True
# 4340               False                  False                    True
#
#                                               review_11  \
# 341   Nemenin anak 4tahun pertama kali nonton biosko...
# 996   [Coffeeshop dan Pastry Shop Lokal yang Strong ...
# 1802  Surabi nya enak dan ngangenin masa kecil di an...
# 1816  biasa na taste makanan di sini Ok Oktadi pas a...
# 2139  Nonton g lengkap rasanya tanpa cemilan, jadi p...
# 2153  Karena aku habis makan siang Nasi Kapau di Sab...
# 2188  karena di sini ramai slalu jadi saya memutuska...
# 2224  Posisinya searea sama Yagami Ramen, tepatnya d...
# 2437  inget waktu smp tiap ke bandung sering mampir ...
# 3002  kafe bromo, salah satu spot makanan yang berad...
# 3092  Bingung mau cari tempat tongkrongan dengan kon...
# 3390  Ada yang jual kopi enak di dalam pasar.Varian ...
# 3466  Ini aq pesen di kala g boleh nongkrong. Dan pr...
# 3651  Pas masuk.. bagus ya tempatnya. Tapi sepi.. ko...
# 3716                                   Tidak ada review
# 3741                                   Tidak ada review
# 3794                                   Tidak ada review
# 3799                                   Tidak ada review
# 3857                                   Tidak ada review
# 3878                                   Tidak ada review
# 3879                                   Tidak ada review
# 3880                                   Tidak ada review
# 3918                                   Tidak ada review
# 4043                                   Tidak ada review
# 4047                                   Tidak ada review
# 4052                                   Tidak ada review
# 4062                                   Tidak ada review
# 4073                                   Tidak ada review
# 4098                                   Tidak ada review
# 4281                                   Tidak ada review
# 4340                                   Tidak ada review
#
#                                               review_12  \
# 341   Belakangan ini susu Oatside lagi naik daun. Be...
# 996   Main ke @mallofindonesia, mampir dulu ke @comm...
# 1802                                   Tidak ada review
# 1816  nyarap jam 09:45 hihi, antreee banget gila ram...
# 2139                                   Tidak ada review
# 2153                                   Tidak ada review
# 2188  Akhir-akhir ini hampir tiap food vlogger pasti...
# 2224                                   Tidak ada review
# 2437  Pagi ini sehabis olahraga jalan pagi aku menco...
# 3002  Lunch kali ini kt cobain all you can eat nya c...
# 3092  Akhirnya kesini setelah sekian lama. Ini sala ...
# 3390                                   Tidak ada review
# 3466                                   Tidak ada review
# 3651                                   Tidak ada review
# 3716                                   Tidak ada review
# 3741                                   Tidak ada review
# 3794                                   Tidak ada review
# 3799                                   Tidak ada review
# 3857                                   Tidak ada review
# 3878                                   Tidak ada review
# 3879                                   Tidak ada review
# 3880                                   Tidak ada review
# 3918                                   Tidak ada review
# 4043                                   Tidak ada review
# 4047                                   Tidak ada review
# 4052                                   Tidak ada review
# 4062                                   Tidak ada review
# 4073                                   Tidak ada review
# 4098                                   Tidak ada review
# 4281                                   Tidak ada review
# 4340                                   Tidak ada review
#
#                                               review_13
# 341   Who is another fan of eating before watching t...
# 996   Hari ini main ke @mallofindonesia karena lagi ...
# 1802                                   Tidak ada review
# 1816  Tempat sarapan yang lagi happening. Sebenarnya...
# 2139                                   Tidak ada review
# 2153                                   Tidak ada review
# 2188  Tempat sarapan ala kopitiam yang lagi hits di ...
# 2224                                   Tidak ada review
# 2437                                   Tidak ada review
# 3002  Makanannya enak2 dan bervariasi dan jg ada mak...
# 3092  First time kesini, untuk coffee break. Pesan n...
# 3390                                   Tidak ada review
# 3466                                   Tidak ada review
# 3651                                   Tidak ada review
# 3716                                   Tidak ada review
# 3741                                   Tidak ada review
# 3794                                   Tidak ada review
# 3799                                   Tidak ada review
# 3857                                   Tidak ada review
# 3878                                   Tidak ada review
# 3879                                   Tidak ada review
# 3880                                   Tidak ada review
# 3918                                   Tidak ada review
# 4043                                   Tidak ada review
# 4047                                   Tidak ada review
# 4052                                   Tidak ada review
# 4062                                   Tidak ada review
# 4073                                   Tidak ada review
# 4098                                   Tidak ada review
# 4281                                   Tidak ada review
# 4340                                   Tidak ada review

# %%
df['cuisine'] = df['cuisine'].fillna('beragam')

# %%
df.isnull().sum()
# Out:
# title                     0
# kota                      0
# full_address              0
# rate                      0
# cuisine                   0
# price_from                0
# price_till                0
# url                       0
# opening_hours             0
# wifi_available            0
# smoking_area_available    0
# outdoor_seat_available    0
# full_time_available       0
# vip_room_available        0
# reservation_available     0
# parking_area_available    0
# review_11                 0
# review_12                 0
# review_13                 0
# dtype: int64

# %%
df
# Out:
#                           title      kota  \
# 0                  Kohicha Cafe   Jakarta
# 1     Hang Tuah Kopi & Toastery   Jakarta
# 2                Toko Kopi Tuku   Jakarta
# 3            Kopi Susu Bu Lurah   Jakarta
# 4             Kopi Selamat Pagi   Jakarta
# ...                         ...       ...
# 4495                    Kitcoff  Surabaya
# 4496                      Avere  Surabaya
# 4497                Kangen Ortu  Surabaya
# 4498                     L'Fash  Surabaya
# 4499         Cerita Kita Eatery  Surabaya
#
#                                            full_address  rate cuisine  \
# 0     Kelapa Gading, Ruko Gading Kirana, Blok A6A No...  4.36    Kafe
# 1     Pecenongan, Jl. Pecenongan No. 37, Pecenongan,...  4.53    Kafe
# 2     Fatmawati, Jl. Cipete Raya No. 7 (Sebelah Alfa...  4.00    Kafe
# 3     Setiabudi, Warung MJS, Jl. Setiabudi Tengah No...  3.93    Kafe
# 4     Kelapa Gading, Jl. Summagung III No. 17, Kelap...  4.34    Kafe
# ...                                                 ...   ...     ...
# 4495  Ngagel, Jl. Ngagel Madya No. 85, Ngagel, Surabaya  0.00    Kafe
# 4496  Ngagel, Jl. Ngagel Jaya Barat No. 52, Ngagel, ...  0.00    Kafe
# 4497  Sukolilo, Jl. Raya Manyar No. 67B, Sukolilo, S...  0.00    Kafe
# 4498  Sukolilo, Jl. Manyar Kartika Barat No. 7, Suko...  0.00    Kafe
# 4499  Wonocolo, Jl. Siwalankerto Timur No. 185, Wono...  0.00    Kafe
#
#       price_from  price_till  \
# 0        50000.0    100000.0
# 1        50000.0    100000.0
# 2            0.0     50000.0
# 3            0.0     50000.0
# 4        50000.0    100000.0
# ...          ...         ...
# 4495         0.0     50000.0
# 4496         0.0     50000.0
# 4497         0.0     50000.0
# 4498         0.0     50000.0
# 4499         0.0     50000.0
#
#                                                     url  \
# 0     https://pergikuliner.com/restaurants/jakarta/k...
# 1     https://pergikuliner.com/restaurants/jakarta/h...
# 2     https://pergikuliner.com/restaurants/jakarta/t...
# 3     https://pergikuliner.com/restaurants/jakarta/k...
# 4     https://pergikuliner.com/restaurants/jakarta/k...
# ...                                                 ...
# 4495  https://pergikuliner.com/restaurants/surabaya/...
# 4496  https://pergikuliner.com/restaurants/surabaya/...
# 4497  https://pergikuliner.com/restaurants/surabaya/...
# 4498  https://pergikuliner.com/restaurants/surabaya/...
# 4499  https://pergikuliner.com/restaurants/surabaya/...
#
#                        opening_hours  wifi_available  smoking_area_available  \
# 0     Senin - Minggu (08:00 - 22:00)            True                    True
# 1     Senin - Minggu (07:00 - 22:00)            True                    True
# 2     Senin - Minggu (07:00 - 21:00)            True                    True
# 3     Senin - Minggu (10:00 - 23:00)            True                    True
# 4     Senin - Minggu (09:00 - 21:00)            True                    True
# ...                              ...             ...                     ...
# 4495  Senin - Minggu (10:00 - 22:00)            True                    True
# 4496  Senin - Minggu (12:00 - 24:00)            True                    True
# 4497  Senin - Minggu (09:30 - 24:00)            True                    True
# 4498  Senin - Minggu (11:00 - 22:00)            True                    True
# 4499  Senin - Minggu (16:00 - 02:00)            True                    True
#
#       outdoor_seat_available  full_time_available  vip_room_available  \
# 0                       True                False               False
# 1                       True                False               False
# 2                       True                False               False
# 3                       True                False                True
# 4                       True                False               False
# ...                      ...                  ...                 ...
# 4495                    True                False               False
# 4496                    True                False               False
# 4497                   False                False               False
# 4498                    True                False                True
# 4499                   False                False                True
#
#       reservation_available  parking_area_available  \
# 0                      True                    True
# 1                      True                    True
# 2                     False                   False
# 3                      True                    True
# 4                      True                    True
# ...                     ...                     ...
# 4495                   True                    True
# 4496                   True                    True
# 4497                  False                    True
# 4498                   True                    True
# 4499                   True                    True
#
#                                               review_11  \
# 0     Food is excellent, absolutely delicious. The p...
# 1     Buka dari pagi, komplir menu sarapan sampe mak...
# 2     Toko tuku pertama kali di cipete ini, ternyata...
# 3     *Review untuk pesan antar (via gojek) atau tak...
# 4     I need my morning coffee. Cuzz ke Kopi Selamat...
# ...                                                 ...
# 4495                                   Tidak ada review
# 4496                                   Tidak ada review
# 4497                                   Tidak ada review
# 4498                                   Tidak ada review
# 4499                                   Tidak ada review
#
#                                               review_12  \
# 0     Makanan disini semua enak. Makanan & minumanny...
# 1     [Breakast Nikmat khas Singapore di Pecenongan ...
# 2     Rasanya beda sama yang biasa saya minum, tapi ...
# 3     Sabtu sore maen kesini khusus buat nyoba es ko...
# 4     Tempatnya enak, cukup nyantai, pet-friendly, a...
# ...                                                 ...
# 4495                                   Tidak ada review
# 4496                                   Tidak ada review
# 4497                                   Tidak ada review
# 4498                                   Tidak ada review
# 4499                                   Tidak ada review
#
#                                               review_13
# 0     Cafe vibes Jepang di Kelapa Gading. Aku surah ...
# 1     kwetiaw seafoodrasanya gurih, smokey flavor. i...
# 2     Akhirnyaa cobain yang slushy juga, dan ini bar...
# 3     Es kopi susu bu lurah salah satu yang gue suka...
# 4     Baru pertama kali coba ke kopi selamat pagi, t...
# ...                                                 ...
# 4495                                   Tidak ada review
# 4496                                   Tidak ada review
# 4497                                   Tidak ada review
# 4498                                   Tidak ada review
# 4499                                   Tidak ada review
#
# [4500 rows x 19 columns]

# %% [markdown]
# ## Save data clean

# %%
# Menyimpan DataFrame ke file CSV
df.to_csv('data_clean.csv', index=False, encoding='utf-8')
